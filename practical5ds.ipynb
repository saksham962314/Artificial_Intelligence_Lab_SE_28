# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham962314/Artificial_Intelligence_Lab_SE_28/blob/master/practical5ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Manipulation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aa5bea67-43f7-4a9d-bf01-a8ed38fdbdb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa5bea67-43f7-4a9d-bf01-a8ed38fdbdb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
# ...

# %% [markdown]
# ##Aggregate Statistics:

# %%
df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
df['age'].describe()
# Out:
# count    5000.000000
# mean       20.520400
# std         2.870406
# min        16.000000
# 25%        18.000000
# 50%        20.000000
# 75%        23.000000
# max        25.000000
# Name: age, dtype: float64

# %% [markdown]
# ##Filtering Data:

# %%
df[(df["age"]>18) & (df['study_hours']> 10)][['student_id','age','study_hours']]
# Out:
#       student_id  age  study_hours
# 1428        1429   22        10.52
# 2095        2096   20        10.49
# 2222        2223   19        10.13
# 2693        2694   22        10.55
# 4354        4355   24        10.11

# %%
 df[df["study_hours"] > 10][['student_id','academic_level','study_hours' ]]
# Out:
#       student_id academic_level  study_hours
# 834          835    High School        10.42
# 1051        1052    High School        10.80
# 1428        1429  Undergraduate        10.52
# 2095        2096   Postgraduate        10.49
# 2222        2223    High School        10.13
# 2693        2694   Postgraduate        10.55
# 3375        3376    High School        11.84
# 4354        4355  Undergraduate        10.11

# %% [markdown]
# ##Grouping Data:

# %%
df.groupby("gender")["productivity_score"].mean()
# Out:
# gender
# Female    37.384601
# Male      37.546038
# Other     36.862532
# Name: productivity_score, dtype: float64

# %%
df.groupby("academic_level")["study_hours"].mean()
# Out:
# academic_level
# High School      4.536531
# Postgraduate     4.512875
# Undergraduate    4.570183
# Name: study_hours, dtype: float64

# %%
df.groupby("academic_level")["screen_time_hours"].mean()
# Out:
# academic_level
# High School      7.071657
# Postgraduate     6.888838
# Undergraduate    6.979074
# Name: screen_time_hours, dtype: float64

# %%
sns.barplot(x="age", y="gaming_hours", data=df)

plt.title("Age vs Gaming_hours")
plt.show()

# %%
plt.pie(df['academic_level'].value_counts(), labels=df['academic_level'].unique(), autopct='%1.1f%%',
        startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c1cd164c2f0>,
# ...
#  [Text(-0.9595767273590969, 0.5377848122723489, 'High School'),
#   Text(0.03178837065036165, -1.099540585649932, 'Undergraduate'),
#   Text(0.9436347694715393, 0.5652905640857584, 'Postgraduate')],
#  [Text(-0.5234054876504164, 0.2933371703303721, '33.7%'),
#   Text(0.017339111263833626, -0.5997494103545083, '33.4%'),
#   Text(0.5147098742572032, 0.3083403076831409, '32.8%')])
